# %%
from datetime import datetime
import io
import itertools
from packaging import version
import pandas as pd
from numpy import array
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras

import numpy as np
import sklearn.metrics
import matplotlib.pyplot as plt

filename = 'U235_2.csv'
data= pd.read_csv(filename)
#names = ['A', 'MASS YIELDS']
#dataset = read_csv(filename, names=names)
#print(dataset1)
#print(dataset.head(0))
print(data.shape)
#print(dataset1)
#data = array(dataset1)

print('Rows: %d' % data.shape[0])
print('Cols: %d' % data.shape[1])
array1 = data.values
X = array1[:,:-1]
y = array1[:,1]
plt.plot(X,y)
plt.yscale('log')
print(X)

print(y)

#pyplot.show()
# Out:
# (106, 2)
# Rows: 106
# Cols: 2
# [[ 67.]
#  [ 68.]
#  [ 69.]
#  [ 70.]
#  [ 71.]
#  [ 72.]
#  [ 73.]
#  [ 74.]
#  [ 75.]
#  [ 76.]
#  [ 77.]
#  [ 78.]
#  [ 79.]
#  [ 80.]
#  [ 81.]
#  [ 82.]
#  [ 83.]
#  [ 84.]
#  [ 85.]
#  [ 86.]
#  [ 87.]
#  [ 88.]
#  [ 89.]
#  [ 90.]
#  [ 91.]
#  [ 92.]
#  [ 93.]
#  [ 94.]
#  [ 95.]
#  [ 96.]
#  [ 97.]
#  [ 98.]
#  [ 99.]
#  [100.]
#  [101.]
#  [102.]
#  [103.]
#  [104.]
#  [105.]
#  [106.]
#  [107.]
#  [108.]
#  [109.]
#  [110.]
#  [111.]
#  [112.]
#  [113.]
#  [114.]
#  [115.]
#  [116.]
#  [117.]
#  [118.]
#  [119.]
#  [120.]
#  [121.]
#  [122.]
#  [123.]
#  [124.]
#  [125.]
#  [126.]
#  [127.]
#  [128.]
#  [129.]
#  [130.]
#  [131.]
#  [132.]
#  [133.]
#  [134.]
#  [135.]
#  [136.]
#  [137.]
#  [138.]
#  [139.]
#  [140.]
#  [141.]
#  [142.]
#  [143.]
#  [144.]
#  [145.]
#  [146.]
#  [147.]
#  [148.]
#  [149.]
#  [150.]
#  [151.]
#  [152.]
#  [153.]
#  [154.]
#  [155.]
#  [156.]
#  [157.]
#  [158.]
#  [159.]
#  [160.]
#  [161.]
#  [162.]
#  [163.]
#  [164.]
#  [165.]
#  [166.]
#  [167.]
#  [168.]
#  [169.]
#  [170.]
#  [171.]
#  [172.]]
# [3.62e-09 8.38e-09 1.48e-08 3.71e-08 8.41e-08 2.66e-07 1.07e-06 3.39e-06
#  1.07e-05 3.09e-05 7.60e-05 2.10e-04 4.48e-04 1.28e-03 1.90e-03 3.27e-03
#  5.36e-03 8.96e-03 1.29e-02 1.41e-02 2.53e-02 3.42e-02 4.76e-02 5.90e-02
#  5.87e-02 5.99e-02 6.25e-02 6.59e-02 6.56e-02 6.37e-02 6.12e-02 5.77e-02
#  6.16e-02 6.59e-02 5.19e-02 4.21e-02 3.04e-02 1.88e-02 9.74e-03 4.03e-03
#  1.47e-03 5.42e-04 3.13e-04 2.56e-04 1.75e-04 1.39e-04 1.38e-04 1.20e-04
#  1.31e-04 1.33e-04 1.18e-04 1.14e-04 1.23e-04 1.26e-04 1.31e-04 1.55e-04
#  1.10e-04 2.69e-04 2.91e-04 5.84e-04 1.53e-03 3.49e-03 5.36e-03 1.82e-02
#  2.89e-02 4.33e-02 6.71e-02 7.87e-02 6.56e-02 6.11e-02 6.36e-02 6.79e-02
#  6.49e-02 6.24e-02 5.87e-02 5.84e-02 5.98e-02 5.52e-02 3.95e-02 3.01e-02
#  2.25e-02 1.68e-02 1.09e-02 6.55e-03 4.13e-03 2.68e-03 1.59e-03 7.46e-04
#  3.22e-04 1.49e-04 6.17e-05 3.29e-05 1.01e-05 3.20e-06 8.55e-07 1.59e-07
#  6.12e-08 1.89e-08 9.54e-09 3.63e-09 2.48e-09 5.73e-10 2.39e-10 5.02e-11
#  2.35e-11 7.71e-12]

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation

from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
X_t = scaler.fit_transform(data)
is_inlier = detector.fit_predict(X_t)
X_t = X_t[(is_inlier > 0),:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a52cb37e5def> in <module>
#      14 scaler=MinMaxScaler()
#      15 X_t = scaler.fit_transform(data)
# ---> 16 is_inlier = detector.fit_predict(X_t)
#      17 X_t = X_t[(is_inlier > 0),:]
#
# NameError: name 'detector' is not defined
